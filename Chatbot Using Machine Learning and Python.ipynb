# %% [markdown]
# # Chatbot with Machine Learning and Python

# %% [markdown]
# A Chatbot is a computer program which is programmed to interact with a human. A chatbot is designed to reply to a human user based on their queries and conversations. If you think chatbots are a new technology, you’re wrong. The first chatbot, Eliza, was built in 1966 at MIT’s Artificial Intelligence Laboratory by Joseph Weizenbaum to mimic human conversations.

# %% [markdown]
# # How Does a Chatbot Work?
# Since we will be developing a Chatbot with Python using Machine Learning, we need some data to train our model. But we’re not going to collect or download a large dataset since this is just a chatbot. We can just create our own dataset to train the model.
# To create this dataset to create a chatbot with Python, we need to understand what intents we are going to train. An “intention” is the user’s intention to interact with a chatbot or the intention behind every message the chatbot receives from a particular user.
#
# Therefore, it is important to understand the good intentions of your chatbot depending on the domain you will be working with. So why does he need to define these intentions? This is a very important point to understand.
#
# In order to answer questions asked by the users and perform various other tasks to continue conversations with the users, the chatbot really needs to understand what users are saying or having ‘intention to do. This is why your chatbot must understand the intentions behind users’ messages.
#
# How can you get your chatbot to understand the intentions so that users feel like they know what they want and provide accurate answers? The strategy here is to set different intents and create training samples for those intents and train your chatbot model with these sample training data as model training data (X) and intents in as model training categories (Y).

# %% [markdown]
# # Create a Chatbot with Python and Machine Learning

# %% [markdown]
# Defining the Intentions of a Chatbot
# Now we need to define a few simple intents and a group of messages that match those intents and also map some responses based on each intent category. I’ll create a JSON file named “intents.json” including this data as follows:
#
# {"intents": [
#     {"tag": "greeting",
#      "patterns": ["Hi", "Hey", "Is anyone there?", "Hello", "Hay"],
#      "responses": ["Hello", "Hi", "Hi there"]
#     },
#     {"tag": "goodbye",
#      "patterns": ["Bye", "See you later", "Goodbye"],
#      "responses": ["See you later", "Have a nice day", "Bye! Come back again"]
#     },
#     {"tag": "thanks",
#      "patterns": ["Thanks", "Thank you", "That's helpful", "Thanks for the help"],
#      "responses": ["Happy to help!", "Any time!", "My pleasure", "You're most welcome!"]
#     },
#     {"tag": "about",
#      "patterns": ["Who are you?", "What are you?", "Who you are?" ],
#      "responses": ["I.m Joana, your bot assistant", "I'm Joana, an Artificial Intelligent bot"]
#     },
#     {"tag": "name",
#     "patterns": ["what is your name", "what should I call you", "whats your name?"],
#     "responses": ["You can call me Joana.", "I'm Joana!", "Just call me as Joana"]
#     },
#     {"tag": "help",
#     "patterns": ["Could you help me?", "give me a hand please", "Can you help?", "What can you do for me?", "I need a support", "I need a help", "support me please"],
#     "responses": ["Tell me how can assist you", "Tell me your problem to assist you", "Yes Sure, How can I support you"]
#     },
#     {"tag": "createaccount",
#     "patterns": ["I need to create a new account", "how to open a new account", "I want to create an account", "can you create an account for me", "how to open a new account"],
#     "responses": ["You can just easily create a new account from our web site", "Just go to our web site and follow the guidelines to create a new account"]
#     },
#     {"tag": "complaint",
#     "patterns": ["have a complaint", "I want to raise a complaint", "there is a complaint about a service"],
#     "responses": ["Please provide us your complaint in order to assist you", "Please mention your complaint, we will reach you and sorry for any inconvenience caused"]
#     }
# ]
# }

# %% [markdown]
# # Data preparation:
# The second step of this task to create a chatbot with Python and Machine Learning is to prepare the data to train our chatbot. I’ll start this step by importing the necessary libraries and packages:

# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# %%
#Now I will read the JSON file and process the required files:

with open('intents.json') as file:
    data = json.load(file)
    
training_sentences = []
training_labels = []
labels = []
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
#Now we need to use the label encoder method provided by the Scikit-Learn library in Python:

lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %%
#Tokenization:

#Now we need to vectorize the data using the Tokenization method to create a chatbot with Python and Machine Learning:

vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %% [markdown]
# # Training a Neural Network
#
# Now the next and most important step in the process of building a chatbot with Python and Machine Learning is to train a neural network. Now, I will train and create a neural network to train our chatbot:

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
epochs = 500
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 16)            16000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 8)                 136
#
# =================================================================
# Total params: 16,680
# Trainable params: 16,680
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 2/2 [==============================] - 1s 17ms/step - loss: 2.0821 - accuracy: 0.1212
# Epoch 2/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0803 - accuracy: 0.1212
# Epoch 3/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0790 - accuracy: 0.1212
# Epoch 4/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0779 - accuracy: 0.1818
# Epoch 5/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0772 - accuracy: 0.2727
# Epoch 6/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0767 - accuracy: 0.3939
# Epoch 7/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0762 - accuracy: 0.3333
# Epoch 8/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0757 - accuracy: 0.3333
# Epoch 9/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0754 - accuracy: 0.3333
# Epoch 10/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0749 - accuracy: 0.3333
# Epoch 11/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0744 - accuracy: 0.3030
# Epoch 12/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0739 - accuracy: 0.3030
# Epoch 13/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0734 - accuracy: 0.3030
# Epoch 14/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0730 - accuracy: 0.3030
# Epoch 15/500
# 2/2 [==============================] - 0s 0s/step - loss: 2.0726 - accuracy: 0.3030
# Epoch 16/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0722 - accuracy: 0.3030
# Epoch 17/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0718 - accuracy: 0.3333
# Epoch 18/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0716 - accuracy: 0.3636
# Epoch 19/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0712 - accuracy: 0.3636
# Epoch 20/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0706 - accuracy: 0.3636
# Epoch 21/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0701 - accuracy: 0.3333
# Epoch 22/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0699 - accuracy: 0.3030
# Epoch 23/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0696 - accuracy: 0.3030
# Epoch 24/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0691 - accuracy: 0.3030
# Epoch 25/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0689 - accuracy: 0.2424
# Epoch 26/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0687 - accuracy: 0.1818
# Epoch 27/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0685 - accuracy: 0.1515
# Epoch 28/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0685 - accuracy: 0.1515
# Epoch 29/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0683 - accuracy: 0.1515
# Epoch 30/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0682 - accuracy: 0.1515
# Epoch 31/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0679 - accuracy: 0.1515
# Epoch 32/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0677 - accuracy: 0.1515
# Epoch 33/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0675 - accuracy: 0.1515
# Epoch 34/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0671 - accuracy: 0.1515
# Epoch 35/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0666 - accuracy: 0.1515
# Epoch 36/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0662 - accuracy: 0.1515
# Epoch 37/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0659 - accuracy: 0.1515
# Epoch 38/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0656 - accuracy: 0.1515
# Epoch 39/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0656 - accuracy: 0.1515
# Epoch 40/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0655 - accuracy: 0.1515
# Epoch 41/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0653 - accuracy: 0.1515
# Epoch 42/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0652 - accuracy: 0.1515
# Epoch 43/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0647 - accuracy: 0.1515
# Epoch 44/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0643 - accuracy: 0.1515
# Epoch 45/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0640 - accuracy: 0.1515
# Epoch 46/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0636 - accuracy: 0.1515
# Epoch 47/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0629 - accuracy: 0.1515
# Epoch 48/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0622 - accuracy: 0.1515
# Epoch 49/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0616 - accuracy: 0.1515
# Epoch 50/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0608 - accuracy: 0.1515
# Epoch 51/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0601 - accuracy: 0.1818
# Epoch 52/500
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0594 - accuracy: 0.2121
# Epoch 53/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0591 - accuracy: 0.2121
# Epoch 54/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0585 - accuracy: 0.2121
# Epoch 55/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0574 - accuracy: 0.2424
# Epoch 56/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0564 - accuracy: 0.2424
# Epoch 57/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0556 - accuracy: 0.3030
# Epoch 58/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0544 - accuracy: 0.3030
# Epoch 59/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0530 - accuracy: 0.3030
# Epoch 60/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0520 - accuracy: 0.3030
# Epoch 61/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0513 - accuracy: 0.3030
# Epoch 62/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0505 - accuracy: 0.2727
# Epoch 63/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0500 - accuracy: 0.3030
# Epoch 64/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0496 - accuracy: 0.3030
# Epoch 65/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0485 - accuracy: 0.3333
# Epoch 66/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0472 - accuracy: 0.3636
# Epoch 67/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0457 - accuracy: 0.3636
# Epoch 68/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0449 - accuracy: 0.3030
# Epoch 69/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0440 - accuracy: 0.3030
# Epoch 70/500
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0430 - accuracy: 0.2727
# Epoch 71/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0412 - accuracy: 0.2727
# Epoch 72/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0390 - accuracy: 0.3636
# Epoch 73/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0376 - accuracy: 0.3939
# Epoch 74/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0368 - accuracy: 0.4242
# Epoch 75/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0359 - accuracy: 0.3636
# Epoch 76/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0347 - accuracy: 0.3636
# Epoch 77/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0332 - accuracy: 0.3939
# Epoch 78/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0313 - accuracy: 0.3636
# Epoch 79/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0295 - accuracy: 0.3636
# Epoch 80/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0282 - accuracy: 0.3333
# Epoch 81/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0272 - accuracy: 0.3636
# Epoch 82/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0269 - accuracy: 0.3030
# Epoch 83/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0272 - accuracy: 0.2727
# Epoch 84/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0282 - accuracy: 0.2424
# Epoch 85/500
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0279 - accuracy: 0.2424
# Epoch 86/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0269 - accuracy: 0.2424
# Epoch 87/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0258 - accuracy: 0.2424
# Epoch 88/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0237 - accuracy: 0.2424
# Epoch 89/500
# 2/2 [==============================] - 0s 0s/step - loss: 2.0203 - accuracy: 0.2424
# Epoch 90/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0169 - accuracy: 0.2727
# Epoch 91/500
# 2/2 [==============================] - 0s 241us/step - loss: 2.0142 - accuracy: 0.2727
# Epoch 92/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0116 - accuracy: 0.2727
# Epoch 93/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0083 - accuracy: 0.2727
# Epoch 94/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0048 - accuracy: 0.3030
# Epoch 95/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0019 - accuracy: 0.3636
# Epoch 96/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9988 - accuracy: 0.3939
# Epoch 97/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9961 - accuracy: 0.4242
# Epoch 98/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9955 - accuracy: 0.3939
# Epoch 99/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9955 - accuracy: 0.3939
# Epoch 100/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9949 - accuracy: 0.3939
# Epoch 101/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9939 - accuracy: 0.3636
# Epoch 102/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9915 - accuracy: 0.3636
# Epoch 103/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9881 - accuracy: 0.3636
# Epoch 104/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9844 - accuracy: 0.3636
# Epoch 105/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9806 - accuracy: 0.3636
# Epoch 106/500
# 2/2 [==============================] - 0s 460us/step - loss: 1.9774 - accuracy: 0.3636
# Epoch 107/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9746 - accuracy: 0.3636
# Epoch 108/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9720 - accuracy: 0.3939
# Epoch 109/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9694 - accuracy: 0.3939
# Epoch 110/500
# 2/2 [==============================] - 0s 0s/step - loss: 1.9669 - accuracy: 0.4242
# Epoch 111/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9641 - accuracy: 0.4545
# Epoch 112/500
# 2/2 [==============================] - 0s 243us/step - loss: 1.9615 - accuracy: 0.4545
# Epoch 113/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9593 - accuracy: 0.4545
# Epoch 114/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9565 - accuracy: 0.4545
# Epoch 115/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9529 - accuracy: 0.4545
# Epoch 116/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9490 - accuracy: 0.4545
# Epoch 117/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9450 - accuracy: 0.4545
# Epoch 118/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9419 - accuracy: 0.4242
# Epoch 119/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9382 - accuracy: 0.4242
# Epoch 120/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9338 - accuracy: 0.4242
# Epoch 121/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9293 - accuracy: 0.4545
# Epoch 122/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9256 - accuracy: 0.4242
# Epoch 123/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9208 - accuracy: 0.4242
# Epoch 124/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9156 - accuracy: 0.3939
# Epoch 125/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9113 - accuracy: 0.3939
# Epoch 126/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9087 - accuracy: 0.3636
# Epoch 127/500
# 2/2 [==============================] - 0s 0s/step - loss: 1.9065 - accuracy: 0.3636
# Epoch 128/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9038 - accuracy: 0.3636
# Epoch 129/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9005 - accuracy: 0.3636
# Epoch 130/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8963 - accuracy: 0.3636
# Epoch 131/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8917 - accuracy: 0.3636
# Epoch 132/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8878 - accuracy: 0.3636
# Epoch 133/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8828 - accuracy: 0.3636
# Epoch 134/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8762 - accuracy: 0.3636
# Epoch 135/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.
500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3139 - accuracy: 0.4545
# Epoch 264/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3101 - accuracy: 0.4545
# Epoch 265/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3073 - accuracy: 0.4545
# Epoch 266/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3053 - accuracy: 0.4545
# Epoch 267/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.3027 - accuracy: 0.4545
# Epoch 268/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2998 - accuracy: 0.4545
# Epoch 269/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2967 - accuracy: 0.4545
# Epoch 270/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2937 - accuracy: 0.4545
# Epoch 271/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2913 - accuracy: 0.3939
# Epoch 272/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2888 - accuracy: 0.3636
# Epoch 273/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.2867 - accuracy: 0.3636
# Epoch 274/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2842 - accuracy: 0.3636
# Epoch 275/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2810 - accuracy: 0.3636
# Epoch 276/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.2781 - accuracy: 0.3939
# Epoch 277/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2758 - accuracy: 0.3939
# Epoch 278/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2737 - accuracy: 0.3939
# Epoch 279/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2716 - accuracy: 0.3636
# Epoch 280/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2692 - accuracy: 0.3939
# Epoch 281/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2669 - accuracy: 0.3939
# Epoch 282/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2649 - accuracy: 0.3939
# Epoch 283/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2631 - accuracy: 0.4545
# Epoch 284/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2618 - accuracy: 0.4545
# Epoch 285/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2611 - accuracy: 0.4545
# Epoch 286/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2602 - accuracy: 0.4545
# Epoch 287/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2575 - accuracy: 0.4545
# Epoch 288/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2538 - accuracy: 0.4545
# Epoch 289/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2504 - accuracy: 0.4545
# Epoch 290/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2474 - accuracy: 0.4545
# Epoch 291/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2451 - accuracy: 0.4545
# Epoch 292/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2433 - accuracy: 0.3636
# Epoch 293/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2405 - accuracy: 0.3636
# Epoch 294/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2382 - accuracy: 0.3636
# Epoch 295/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2352 - accuracy: 0.3636
# Epoch 296/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2321 - accuracy: 0.3636
# Epoch 297/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2283 - accuracy: 0.3636
# Epoch 298/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.2242 - accuracy: 0.3636
# Epoch 299/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2202 - accuracy: 0.4545
# Epoch 300/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2182 - accuracy: 0.4545
# Epoch 301/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2173 - accuracy: 0.4545
# Epoch 302/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2160 - accuracy: 0.4545
# Epoch 303/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2138 - accuracy: 0.4545
# Epoch 304/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2119 - accuracy: 0.4545
# Epoch 305/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2097 - accuracy: 0.4545
# Epoch 306/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2058 - accuracy: 0.4545
# Epoch 307/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2014 - accuracy: 0.4545
# Epoch 308/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1989 - accuracy: 0.4545
# Epoch 309/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1980 - accuracy: 0.4545
# Epoch 310/500
# 2/2 [==============================] - 0s 0s/step - loss: 1.1970 - accuracy: 0.4545
# Epoch 311/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1941 - accuracy: 0.4848
# Epoch 312/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1903 - accuracy: 0.4848
# Epoch 313/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1870 - accuracy: 0.4848
# Epoch 314/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1838 - accuracy: 0.4848
# Epoch 315/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1809 - accuracy: 0.4848
# Epoch 316/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1783 - accuracy: 0.4848
# Epoch 317/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1753 - accuracy: 0.4848
# Epoch 318/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1723 - accuracy: 0.4848
# Epoch 319/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1691 - accuracy: 0.4848
# Epoch 320/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1659 - accuracy: 0.4848
# Epoch 321/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1633 - accuracy: 0.4848
# Epoch 322/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1606 - accuracy: 0.4848
# Epoch 323/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.1578 - accuracy: 0.4848
# Epoch 324/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1555 - accuracy: 0.4848
# Epoch 325/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1540 - accuracy: 0.4848
# Epoch 326/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1530 - accuracy: 0.4848
# Epoch 327/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1506 - accuracy: 0.4848
# Epoch 328/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.1462 - accuracy: 0.4848
# Epoch 329/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1437 - accuracy: 0.5152
# Epoch 330/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1418 - accuracy: 0.5152
# Epoch 331/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1409 - accuracy: 0.5152
# Epoch 332/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1391 - accuracy: 0.5152
# Epoch 333/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1362 - accuracy: 0.5152
# Epoch 334/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.1342 - accuracy: 0.5455
# Epoch 335/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1324 - accuracy: 0.5455
# Epoch 336/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.1311 - accuracy: 0.5455
# Epoch 337/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1300 - accuracy: 0.5455
# Epoch 338/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.1296 - accuracy: 0.5758
# Epoch 339/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1302 - accuracy: 0.5758
# Epoch 340/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1303 - accuracy: 0.5758
# Epoch 341/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1281 - accuracy: 0.5758
# Epoch 342/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1233 - accuracy: 0.6061
# Epoch 343/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1180 - accuracy: 0.6061
# Epoch 344/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1156 - accuracy: 0.6061
# Epoch 345/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1141 - accuracy: 0.6061
# Epoch 346/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1122 - accuracy: 0.6667
# Epoch 347/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1101 - accuracy: 0.6667
# Epoch 348/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1077 - accuracy: 0.6667
# Epoch 349/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1049 - accuracy: 0.6667
# Epoch 350/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1030 - accuracy: 0.6667
# Epoch 351/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0998 - accuracy: 0.6667
# Epoch 352/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0969 - accuracy: 0.6061
# Epoch 353/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0943 - accuracy: 0.6061
# Epoch 354/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0925 - accuracy: 0.6061
# Epoch 355/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0907 - accuracy: 0.6061
# Epoch 356/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0874 - accuracy: 0.6061
# Epoch 357/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0838 - accuracy: 0.6061
# Epoch 358/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0809 - accuracy: 0.6364
# Epoch 359/500
# 2/2 [==============================] - 0s 923us/step - loss: 1.0788 - accuracy: 0.6364
# Epoch 360/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0770 - accuracy: 0.6364
# Epoch 361/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0754 - accuracy: 0.6061
# Epoch 362/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0733 - accuracy: 0.6364
# Epoch 363/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0712 - accuracy: 0.6364
# Epoch 364/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0693 - accuracy: 0.6364
# Epoch 365/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0675 - accuracy: 0.6061
# Epoch 366/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0659 - accuracy: 0.6061
# Epoch 367/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0634 - accuracy: 0.6061
# Epoch 368/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0613 - accuracy: 0.6061
# Epoch 369/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0588 - accuracy: 0.6364
# Epoch 370/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0569 - accuracy: 0.6364
# Epoch 371/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0550 - accuracy: 0.6667
# Epoch 372/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0534 - accuracy: 0.6364
# Epoch 373/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0524 - accuracy: 0.6364
# Epoch 374/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0505 - accuracy: 0.6364
# Epoch 375/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0478 - accuracy: 0.6364
# Epoch 376/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0455 - accuracy: 0.6364
# Epoch 377/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0433 - accuracy: 0.6364
# Epoch 378/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0411 - accuracy: 0.6667
# Epoch 379/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0398 - accuracy: 0.6364
# Epoch 380/500
# 2/2 [==============================] - 0s 0s/step - loss: 1.0378 - accuracy: 0.6364
# Epoch 381/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0346 - accuracy: 0.6364
# Epoch 382/500
# 2/2 [==============================] - 0s 944us/step - loss: 1.0319 - accuracy: 0.7273
# Epoch 383/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0335 - accuracy: 0.6970
# Epoch 384/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0389 - accuracy: 0.7273
# Epoch 385/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0424 - accuracy: 0.7273
# Epoch 386/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0414 - accuracy: 0.7273
# Epoch 387/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0363 - accuracy: 0.7576
# Epoch 388/500
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0283 - accuracy: 0.7576
# Epoch 389/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0214 - accuracy: 0.6364
# Epoch 390/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0192 - accuracy: 0.6364
# Epoch 391/500
# 2/2 [==============================] - 0s 962us/step - loss: 1.0173 - accuracy: 0.6061
# Epoch 392/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0148 - accuracy: 0.6061
# Epoch 393/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0125 - accuracy: 0.5758
# Epoch 394/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0101 - accuracy: 0.5455
# Epoch 395/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0087 - accuracy: 0.5455
# Epoch 396/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0087 - accuracy: 0.5152
# Epoch 397/500
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0065 - accuracy: 0.5455
# Epoch 398/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0027 - accuracy: 0.5455
# Epoch 399/500
# 2/2 [==============================] - 0s 602us/step - loss: 0.9987 - accuracy: 0.5455
# Epoch 400/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9965 - accuracy: 0.5758
# Epoch 401/500
# 2/2 [==============================] - 0s 847us/step - loss: 0.9954 - accuracy: 0.5758
# Epoch 402/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9938 - accuracy: 0.5758
# Epoch 403/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9911 - accuracy: 0.5758
# Epoch 404/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9886 - accuracy: 0.5758
# Epoch 405/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9870 - accuracy: 0.6061
# Epoch 406/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9855 - accuracy: 0.6061
# Epoch 407/500
# 2/2 [==============================] - 0s 993us/step - loss: 0.9854 - accuracy: 0.5758
# Epoch 408/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9845 - accuracy: 0.6061
# Epoch 409/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9834 - accuracy: 0.6667
# Epoch 410/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9824 - accuracy: 0.6061
# Epoch 411/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9818 - accuracy: 0.6061
# Epoch 412/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9799 - accuracy: 0.6061
# Epoch 413/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9770 - accuracy: 0.6061
# Epoch 414/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9747 - accuracy: 0.6061
# Epoch 415/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9740 - accuracy: 0.6061
# Epoch 416/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9731 - accuracy: 0.6061
# Epoch 417/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9710 - accuracy: 0.6061
# Epoch 418/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9682 - accuracy: 0.6061
# Epoch 419/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9656 - accuracy: 0.5758
# Epoch 420/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9647 - accuracy: 0.5758
# Epoch 421/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9640 - accuracy: 0.5758
# Epoch 422/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9629 - accuracy: 0.5758
# Epoch 423/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9643 - accuracy: 0.5758
# Epoch 424/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9704 - accuracy: 0.5758
# Epoch 425/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9760 - accuracy: 0.5455
# Epoch 426/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9744 - accuracy: 0.5455
# Epoch 427/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9730 - accuracy: 0.5455
# Epoch 428/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9707 - accuracy: 0.5455
# Epoch 429/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9630 - accuracy: 0.5455
# Epoch 430/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9553 - accuracy: 0.5455
# Epoch 431/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9487 - accuracy: 0.5455
# Epoch 432/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9457 - accuracy: 0.5455
# Epoch 433/500
# 2/2 [==============================] - 0s 0s/step - loss: 0.9466 - accuracy: 0.5455
# Epoch 434/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9478 - accuracy: 0.5455
# Epoch 435/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9487 - accuracy: 0.5758
# Epoch 436/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9469 - accuracy: 0.5758
# Epoch 437/500
# 2/2 [==============================] - 0s 562us/step - loss: 0.9392 - accuracy: 0.5758
# Epoch 438/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9293 - accuracy: 0.5758
# Epoch 439/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9232 - accuracy: 0.5758
# Epoch 440/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9174 - accuracy: 0.5758
# Epoch 441/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9115 - accuracy: 0.5758
# Epoch 442/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9071 - accuracy: 0.5758
# Epoch 443/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9037 - accuracy: 0.5758
# Epoch 444/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9015 - accuracy: 0.5758
# Epoch 445/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9004 - accuracy: 0.5758
# Epoch 446/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8984 - accuracy: 0.5758
# Epoch 447/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8958 - accuracy: 0.5758
# Epoch 448/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8929 - accuracy: 0.5758
# Epoch 449/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8901 - accuracy: 0.5758
# Epoch 450/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8879 - accuracy: 0.5758
# Epoch 451/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8867 - accuracy: 0.5758
# Epoch 452/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8858 - accuracy: 0.5758
# Epoch 453/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8844 - accuracy: 0.5758
# Epoch 454/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8810 - accuracy: 0.6061
# Epoch 455/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8789 - accuracy: 0.6667
# Epoch 456/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8782 - accuracy: 0.6667
# Epoch 457/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8824 - accuracy: 0.6667
# Epoch 458/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8857 - accuracy: 0.6667
# Epoch 459/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8841 - accuracy: 0.6667
# Epoch 460/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8827 - accuracy: 0.6667
# Epoch 461/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8821 - accuracy: 0.6667
# Epoch 462/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8791 - accuracy: 0.6667
# Epoch 463/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8775 - accuracy: 0.6364
# Epoch 464/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8768 - accuracy: 0.6364
# Epoch 465/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8766 - accuracy: 0.6970
# Epoch 466/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8761 - accuracy: 0.6970
# Epoch 467/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8760 - accuracy: 0.6364
# Epoch 468/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8745 - accuracy: 0.6364
# Epoch 469/500
# 2/2 [==============================] - 0s 0s/step - loss: 0.8712 - accuracy: 0.6364
# Epoch 470/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8670 - accuracy: 0.6364
# Epoch 471/500
# 2/2 [==============================] - 0s 0s/step - loss: 0.8614 - accuracy: 0.6061
# Epoch 472/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8556 - accuracy: 0.6061
# Epoch 473/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8503 - accuracy: 0.6364
# Epoch 474/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8459 - accuracy: 0.6364
# Epoch 475/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8421 - accuracy: 0.6364
# Epoch 476/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8395 - accuracy: 0.6364
# Epoch 477/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8378 - accuracy: 0.6061
# Epoch 478/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8361 - accuracy: 0.6061
# Epoch 479/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8342 - accuracy: 0.6061
# Epoch 480/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8325 - accuracy: 0.6061
# Epoch 481/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8300 - accuracy: 0.6061
# Epoch 482/500
# 2/2 [==============================] - 0s 984us/step - loss: 0.8262 - accuracy: 0.6061
# Epoch 483/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8226 - accuracy: 0.6364
# Epoch 484/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8188 - accuracy: 0.6364
# Epoch 485/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8153 - accuracy: 0.6364
# Epoch 486/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8124 - accuracy: 0.6364
# Epoch 487/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8094 - accuracy: 0.6364
# Epoch 488/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8069 - accuracy: 0.6364
# Epoch 489/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8061 - accuracy: 0.6364
# Epoch 490/500
# 2/2 [==============================] - 0s 980us/step - loss: 0.8063 - accuracy: 0.6364
# Epoch 491/500
# 2/2 [==============================] - 0s 0s/step - loss: 0.8027 - accuracy: 0.6970
# Epoch 492/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7975 - accuracy: 0.6970
# Epoch 493/500
# 2/2 [==============================] - 0s 971us/step - loss: 0.7957 - accuracy: 0.6970
# Epoch 494/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7974 - accuracy: 0.7576
# Epoch 495/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8003 - accuracy: 0.7576
# Epoch 496/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7999 - accuracy: 0.6970
# Epoch 497/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7934 - accuracy: 0.6970
# Epoch 498/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7863 - accuracy: 0.6970
# Epoch 499/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7845 - accuracy: 0.6970
# Epoch 500/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7830 - accuracy: 0.6667

# %% [markdown]
# # Saving The Neural Network:
# We’ve trained the model, but before we go any further in the process of building a chatbot with Python and Machine Learning, let’s save the model so that we can use this neural network in the future as well:

# %%
# to save the trained model
model.save("chat_model")

import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model\assets

# %% [markdown]
# # Now let’s Build a Chatbot with Python and our Trained Machine Learning Model
#
# Now I am going to implement a chat function to interact with a real user. When the message from the user will be received, the chatbot will compute the similarity between the sequence of the new text and the training data.
#
# Taking into account the trust scores obtained for each category, it categorizes the user’s message according to an intention with the highest trust score:

# %%
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

import colorama 
colorama.init()
from colorama import Fore, Style, Back

import random
import pickle

with open("intents.json") as file:
    data = json.load(file)


def chat():
    # load trained model
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    while True:
        print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
        inp = input()
        if inp.lower() == "quit":
            break

        result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp]),
                                             truncating='post', maxlen=max_len))
        tag = lbl_encoder.inverse_transform([np.argmax(result)])

        for i in data['intents']:
            if i['tag'] == tag:
                print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i['responses']))

        # print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL,random.choice(responses))

print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
chat()
# Out:
# Start messaging with the bot (type quit to stop)!
# User:

# %%
# Summary

This is how we can create a chatbot with Python and Machine Learning.
